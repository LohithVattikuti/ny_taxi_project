# %%
import subprocess
subprocess.run(["python", "-m", "pipeline. feature_pipeline"])
# Out:
# /opt/anaconda3/envs/lohith_env/bin/python: No module named pipeline. feature_pipeline
# CompletedProcess(args=['python', '-m', 'pipeline. feature_pipeline'], returncode=1)

# %%
import subprocess
subprocess.run(["python", "-m", "pipeline. inferernce_pipeline"])
# Out:
# /opt/anaconda3/envs/lohith_env/bin/python: No module named pipeline. inferernce_pipeline
# CompletedProcess(args=['python', '-m', 'pipeline. inferernce_pipeline'], returncode=1)

# %%
import subprocess
subprocess.run(["python", "-m", "pipeline. model_training_pipeline"])
# Out:
# /opt/anaconda3/envs/lohith_env/bin/python: No module named pipeline. model_training_pipeline
# CompletedProcess(args=['python', '-m', 'pipeline. model_training_pipeline'], returncode=1)
